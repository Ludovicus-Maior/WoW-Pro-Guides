# %%
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(20,10)

# %%
data = pandas.DataFrame.from_csv("S3.csv")
data.index = pandas.to_datetime(data.index)
data = data.iloc[:,21:]

# %%
data.plot(kind='area')

# %%
data.sum(axis=0)
# Out:
# Ludo_Ace_and_TomTom_for_WoD_2014_1010.zip      263
# Ludo_TomTom_for_WoD_2014_1018.zip              628
# Ludo_TomTom_for_WoD_2014_1019.zip              254
# WoWPro%2Bv2.4.1.zip                              5
# WoWPro%2Bv2.4.2.zip                              6
# WoWPro%2Bv2.4.3.zip                             36
# WoWPro%2Bv2.4.3A.zip                             4
# WoWPro%2Bv2.5.0.zip                              5
# WoWPro%2Bv2.6.0a.zip                           117
# WoWPro%2Bv2.6.1.zip                              2
# WoWPro%2Bv2.6.2.zip                              8
# WoWPro%2Bv2.6.3.zip                            139
# WoWPro%2Bv2.6.4.zip                              2
# WoWPro%2Bv2.7.0.zip                             10
# WoWPro%2Bv2.7.1.zip                             37
# WoWPro%2Bv2.7.2.zip                              3
# WoWPro%2Bv2.7.3.zip                              5
# WoWPro%2Bv2.7.4A.zip                             6
# ...

# %%
data["2014"].dropna(axis=1, how='all').plot(kind='area')
data["2014"].dropna(axis=1, how='all')
# Out:
#             WoWPro%2Bv6.0.0.zip  WoWPro%2Bv6.0.0A.zip  WoWPro%2Bv6.0.0B.zip  \
# 2014-10-19                  NaN                   NaN                     1
# 2014-10-20                    1                   NaN                     3
# 2014-10-21                  NaN                   NaN                     3
# 2014-10-22                    3                   NaN                   NaN
# 2014-10-23                  NaN                   NaN                   NaN
# 2014-10-24                  NaN                   NaN                     1
# 2014-10-25                  NaN                   NaN                   NaN
# 2014-10-26                  NaN                   NaN                   NaN
# 2014-10-27                  NaN                   NaN                   NaN
# 2014-10-28                  NaN                   NaN                   NaN
# 2014-10-29                  NaN                   NaN                   NaN
# ...

# %%
data["2015"].dropna(axis=1, how='all').plot(kind='area')
data["2015"].dropna(axis=1, how='all').sum(axis=0)
# Out:
# WoWPro%2Bv6.0.0.zip         2
# WoWPro%2Bv6.0.0B.zip        7
# WoWPro%2Bv6.0.0D.zip        2
# WoWPro%2Bv6.0.0E.zip       92
# WoWPro%2Bv6.0.1.zip       610
# WoWPro%2Bv6.0.2A.zip      770
# WoWPro%2Bv6.0.3.zip         1
# WoWPro%2Bv6.0.3B.zip        1
# WoWPro%2Bv6.0.3G.zip        2
# WoWPro%2Bv6.0.3H.zip     1768
# WoWPro%2Bv6.0.3J.zip     8182
# WoWPro%2Bv6.0.4.zip      7373
# WoWPro%2Bv6.1.0.zip      4234
# WoWPro%2Bv6.1.1.zip      1425
# WoWPro%2Bv6.1.1A.zip    13647
# WoWPro%2Bv6.1.2.zip      3929
# WoWPro%2Bv6.2.0.zip      2417
# WoWPro%2Bv6.2.0A.zip     2141
# WoWPro%2Bv6.2.0B.zip      434
# dtype: float64
