# %%
import pandas
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %matplotlib inline
plt.rcParams['figure.figsize']=(20,10)

# %%
data = pandas.DataFrame.from_csv("S3.csv")
data.index = pandas.to_datetime(data.index)
data = data.iloc[:,21:]
data.columns = map(lambda c: c[9:], data.columns)

# %%
data.plot(kind='area')

# %%
data.sum(axis=0)
# Out:
# v2.7.3.zip                 23
# v2.7.4.zip                  2
# v2.7.4A.zip                25
# v2.7.5.zip                  2
# v2.7.5A.zip                 1
# v2.7.5B.zip                34
# v2.7.6.zip                  1
# v2.7.6A.zip                28
# v2.7.7.zip                242
# v6.0.0.zip                  8
# v6.0.0A.zip                 5
# v6.0.0B.zip                28
# v6.0.0C.zip               986
# v6.0.0D.zip              1786
# v6.0.0E.zip              4098
# v6.0.1.zip               7575
# v6.0.2.zip               1870
# v6.0.2A.zip              4766
# v6.0.3.zip               1777
# v6.0.3A.zip              2289
# v6.0.3B.zip              3241
# v6.0.3C.zip              4188
# v6.0.3D.zip               701
# v6.0.3E.zip              3451
# v6.0.3F.zip              4189
# v6.0.3G.zip              1975
# v6.0.3H.zip             12939
# v6.0.3J.zip              8208
# v6.0.4.zip               7405
# v6.1.0.zip               4260
# v6.1.1.zip               1426
# v6.1.1A.zip             13692
# v6.1.2.zip               4036
# v6.2.0.zip               2707
# v6.2.0A.zip              2143
# v6.2.0B.zip              1540
# v6.2.0C.zip              1208
# v6.2.0D.zip              4079
# v6.2.0E.zip              3523
# v6.2.0F.zip              1216
# v6.2.2.zip               5173
# v6.2.2A.zip             12840
# v6.2.3.zip               8930
# v6.2.4.zip              17223
# v7.0.3H.zip              6167
# v7.0.3I.zip              1293
# v7.0.3J.zip              3294
# v7.0.3K.zip               786
# v7.0.3L.zip              3814
# v7.0.3M.zip              5515
# v7.0.3N.zip              8172
# v7.0.3O.zip              9145
# v7.0.3P.zip              4770
# v7.0.3Q.zip              6722
# v7.0.4.zip                  1
# v7.0.4A.zip               706
# veling%2Bv0.12.2.zip        1
# veling%2Bv0.12.3.zip        1
# dtype: float64

# %%
x=data["2014"].dropna(axis=1, how='all')
# x = x.iloc[: , :-2]
ax=x.plot(kind='area', title="WoWPro Downloads 2014", figsize=(20,10))
ax.legend(loc='upper left', bbox_to_anchor=(0.6, 1.05),
          ncol=4, fancybox=True, shadow=True)

# %%
x = data["2015"].dropna(axis=1, how='all')
x = x.iloc[: , 9:]
ax=x.plot(kind='area', title="WoWPro Downloads 2015", figsize=(20,10))
ax.legend(loc='upper left', bbox_to_anchor=(0.6, 1.05),
          ncol=4, fancybox=True, shadow=True)
#ax.set_ylim(0,1000)
x.sum(axis=0)
# Out:
# v6.0.0D.zip        8
# v6.0.0E.zip      126
# v6.0.1.zip       622
# v6.0.2.zip         6
# v6.0.2A.zip      803
# v6.0.3.zip         1
# v6.0.3B.zip        1
# v6.0.3G.zip        2
# v6.0.3H.zip     1788
# v6.0.3J.zip     8200
# v6.0.4.zip      7397
# v6.1.0.zip      4253
# v6.1.1.zip      1425
# v6.1.1A.zip    13683
# v6.1.2.zip      4023
# v6.2.0.zip      2693
# v6.2.0A.zip     2142
# v6.2.0B.zip     1538
# v6.2.0C.zip     1207
# v6.2.0D.zip     4073
# v6.2.0E.zip     3522
# v6.2.0F.zip     1180
# v6.2.2.zip      5056
# v6.2.2A.zip    11300
# dtype: float64

# %%
x = data["2016"].dropna(axis=1, how='all')
x = x.iloc[: , :-2]
ax=x.plot(kind='area', title="WoWPro Downloads 2016", figsize=(20,10))
ax.legend(loc='upper right', bbox_to_anchor=(0.5, 0.95),
          ncol=4, fancybox=True, shadow=True)
#ax.set_ylim(0,1000)
x.sum(axis=0)
# Out:
# v2.7.3.zip        10
# v2.7.4.zip         2
# v2.7.4A.zip       10
# v2.7.5.zip         1
# v2.7.5A.zip        1
# v2.7.5B.zip       14
# v2.7.6.zip         1
# v2.7.6A.zip       11
# v2.7.7.zip        97
# v6.0.0.zip         1
# v6.0.0A.zip        1
# v6.0.0B.zip        5
# v6.0.0C.zip        7
# v6.0.0D.zip        6
# v6.0.0E.zip       11
# v6.0.1.zip         9
# v6.0.2.zip         5
# v6.0.2A.zip       11
# v6.0.3.zip         2
# v6.0.3A.zip        2
# v6.0.3B.zip        1
# v6.0.3C.zip        1
# v6.0.3D.zip        1
# v6.0.3E.zip        1
# v6.0.3F.zip        1
# v6.0.3G.zip        1
# v6.0.3H.zip        9
# v6.0.3J.zip        8
# v6.0.4.zip         8
# v6.1.0.zip         7
# v6.1.1.zip         1
# v6.1.1A.zip        9
# v6.1.2.zip        13
# v6.2.0.zip        14
# v6.2.0A.zip        1
# v6.2.0B.zip        2
# v6.2.0C.zip        1
# v6.2.0D.zip        6
# v6.2.0E.zip        1
# v6.2.0F.zip       36
# v6.2.2.zip       117
# v6.2.2A.zip     1540
# v6.2.3.zip      8930
# v6.2.4.zip     17223
# v7.0.3H.zip     6167
# v7.0.3I.zip     1293
# v7.0.3J.zip     3294
# v7.0.3K.zip      786
# v7.0.3L.zip     3814
# v7.0.3M.zip     5515
# v7.0.3N.zip     8172
# v7.0.3O.zip     9145
# v7.0.3P.zip     4770
# v7.0.3Q.zip     6722
# v7.0.4.zip         1
# v7.0.4A.zip      706
# dtype: float64

# %%
x = data["2016"].dropna(axis=1, how='all')
x = x.iloc[: , -14:-2].dropna(axis=0, how='all')
ax=x.plot(kind='area', title="WoWPro Legion Downloads 2016", figsize=(20,10))
ax.legend(loc='upper left', bbox_to_anchor=(0.5, 0.95),
          ncol=4, fancybox=True, shadow=True)
#ax.set_ylim(0,1000)
x.sum(axis=0)
# Out:
# v7.0.3H.zip    6167
# v7.0.3I.zip    1293
# v7.0.3J.zip    3294
# v7.0.3K.zip     786
# v7.0.3L.zip    3814
# v7.0.3M.zip    5515
# v7.0.3N.zip    8172
# v7.0.3O.zip    9145
# v7.0.3P.zip    4770
# v7.0.3Q.zip    6722
# v7.0.4.zip        1
# v7.0.4A.zip     706
# dtype: float64

# %%
x.resample('D', how='mean')
# Out:
#             v7.0.3M.zip  v7.0.3N.zip  v7.0.3O.zip  v7.0.3P.zip  v7.0.3Q.zip  \
# 2016-08-19          257          NaN          NaN          NaN          NaN
# 2016-08-20          499          NaN          NaN          NaN          NaN
# 2016-08-21          406          NaN          NaN          NaN          NaN
# 2016-08-22          332          NaN          NaN          NaN          NaN
# 2016-08-23          281          NaN          NaN          NaN          NaN
# 2016-08-24          258          NaN          NaN          NaN          NaN
# 2016-08-25          220          NaN          NaN          NaN          NaN
# 2016-08-26          242          NaN          NaN          NaN          NaN
# 2016-08-27          273          NaN          NaN          NaN          NaN
# 2016-08-28          312          NaN          NaN          NaN          NaN
# 2016-08-29          577          NaN          NaN          NaN          NaN
# 2016-08-30         1690          NaN          NaN          NaN          NaN
# 2016-08-31          118         2933          NaN          NaN          NaN
# 2016-09-01            9         1253          NaN          NaN          NaN
# 2016-09-02            5          935          NaN          NaN          NaN
# 2016-09-03            6          931          NaN          NaN          NaN
# 2016-09-04            5          870          NaN          NaN          NaN
# 2016-09-05            5          702          NaN          NaN          NaN
# 2016-09-06            3          484          214          NaN          NaN
# 2016-09-07            1           16         1429          NaN          NaN
# 2016-09-08            1            7          952          NaN          NaN
# 2016-09-09            1            8          797          NaN          NaN
# 2016-09-10            1            6          863          NaN          NaN
# 2016-09-11            2            4          834          NaN          NaN
# 2016-09-12            2            1          561          NaN          NaN
# 2016-09-13          NaN            1          524          NaN          NaN
# 2016-09-14            2            2          447          NaN          NaN
# 2016-09-15            1            2          480          NaN          NaN
# 2016-09-16          NaN            2          468          NaN          NaN
# 2016-09-17          NaN            1          580          NaN          NaN
# 2016-09-18          NaN            4          566          NaN          NaN
# 2016-09-19          NaN          NaN          364          NaN          NaN
# 2016-09-20            2            2           33          863          NaN
# 2016-09-21          NaN          NaN            1          618          NaN
# 2016-09-22            1            1            1          542          NaN
# 2016-09-23            1          NaN            4          516          NaN
# 2016-09-24          NaN          NaN            3          468          NaN
# 2016-09-25            1            1            7          612          NaN
# 2016-09-26            1          NaN            5          377          NaN
# 2016-09-27          NaN          NaN            1          347          NaN
# 2016-09-28          NaN            1            1          341          NaN
# 2016-09-29          NaN            1          NaN           48          662
# 2016-09-30          NaN          NaN            2            2          528
# 2016-10-01          NaN            1            1            3          653
# 2016-10-02          NaN          NaN            1            4          603
# 2016-10-03          NaN          NaN          NaN            4          403
# 2016-10-04          NaN          NaN            1            4          411
# 2016-10-05          NaN          NaN            3            2          379
# 2016-10-06          NaN          NaN          NaN            4          353
# 2016-10-07          NaN            1          NaN            1          315
# 2016-10-08          NaN            1          NaN            1          453
# 2016-10-09          NaN          NaN          NaN            1          383
# 2016-10-10          NaN          NaN            1            3          305
# 2016-10-11          NaN          NaN          NaN          NaN          242
# 2016-10-12          NaN          NaN          NaN            1          237
# 2016-10-13          NaN          NaN            1          NaN          270
# 2016-10-14          NaN          NaN          NaN            4          249
# 2016-10-15          NaN          NaN          NaN            4          228
# 2016-10-16          NaN            1          NaN          NaN           48
#
#             v7.0.4.zip  v7.0.4A.zip
# 2016-08-19         NaN          NaN
# 2016-08-20         NaN          NaN
# 2016-08-21         NaN          NaN
# 2016-08-22         NaN          NaN
# 2016-08-23         NaN          NaN
# 2016-08-24         NaN          NaN
# 2016-08-25         NaN          NaN
# 2016-08-26         NaN          NaN
# 2016-08-27         NaN          NaN
# 2016-08-28         NaN          NaN
# 2016-08-29         NaN          NaN
# 2016-08-30         NaN          NaN
# 2016-08-31         NaN          NaN
# 2016-09-01         NaN          NaN
# 2016-09-02         NaN          NaN
# 2016-09-03         NaN          NaN
# 2016-09-04         NaN          NaN
# 2016-09-05         NaN          NaN
# 2016-09-06         NaN          NaN
# 2016-09-07         NaN          NaN
# 2016-09-08         NaN          NaN
# 2016-09-09         NaN          NaN
# 2016-09-10         NaN          NaN
# 2016-09-11         NaN          NaN
# 2016-09-12         NaN          NaN
# 2016-09-13         NaN          NaN
# 2016-09-14         NaN          NaN
# 2016-09-15         NaN          NaN
# 2016-09-16         NaN          NaN
# 2016-09-17         NaN          NaN
# 2016-09-18         NaN          NaN
# 2016-09-19         NaN          NaN
# 2016-09-20         NaN          NaN
# 2016-09-21         NaN          NaN
# 2016-09-22         NaN          NaN
# 2016-09-23         NaN          NaN
# 2016-09-24         NaN          NaN
# 2016-09-25         NaN          NaN
# 2016-09-26         NaN          NaN
# 2016-09-27         NaN          NaN
# 2016-09-28         NaN          NaN
# 2016-09-29         NaN          NaN
# 2016-09-30         NaN          NaN
# 2016-10-01         NaN          NaN
# 2016-10-02         NaN          NaN
# 2016-10-03         NaN          NaN
# 2016-10-04         NaN          NaN
# 2016-10-05         NaN          NaN
# 2016-10-06         NaN          NaN
# 2016-10-07         NaN          NaN
# 2016-10-08         NaN          NaN
# 2016-10-09         NaN          NaN
# 2016-10-10         NaN          NaN
# 2016-10-11         NaN          NaN
# 2016-10-12         NaN          NaN
# 2016-10-13         NaN          NaN
# 2016-10-14         NaN          NaN
# 2016-10-15           1          NaN
# 2016-10-16         NaN          706
