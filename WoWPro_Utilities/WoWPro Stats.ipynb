# %%
import pandas
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %matplotlib inline
plt.rcParams['figure.figsize']=(20,10)

# %%
data = pandas.DataFrame.from_csv("S3.csv")
data.index = pandas.to_datetime(data.index)
data = data.iloc[:,21:]
data.columns = map(lambda c: c[9:], data.columns)

# %%
data.plot(kind='area')

# %%
data.sum(axis=0)
# Out:
# v2.7.3.zip                 23
# v2.7.4.zip                  2
# v2.7.4A.zip                25
# v2.7.5.zip                  2
# v2.7.5A.zip                 1
# v2.7.5B.zip                34
# v2.7.6.zip                  1
# v2.7.6A.zip                28
# v2.7.7.zip                227
# v6.0.0.zip                  8
# v6.0.0A.zip                 5
# v6.0.0B.zip                28
# v6.0.0C.zip               986
# v6.0.0D.zip              1786
# v6.0.0E.zip              4098
# v6.0.1.zip               7575
# v6.0.2.zip               1870
# v6.0.2A.zip              4766
# v6.0.3.zip               1777
# v6.0.3A.zip              2289
# v6.0.3B.zip              3241
# v6.0.3C.zip              4188
# v6.0.3D.zip               701
# v6.0.3E.zip              3451
# v6.0.3F.zip              4189
# v6.0.3G.zip              1975
# v6.0.3H.zip             12939
# v6.0.3J.zip              8208
# v6.0.4.zip               7405
# v6.1.0.zip               4260
# v6.1.1.zip               1426
# v6.1.1A.zip             13692
# v6.1.2.zip               4036
# v6.2.0.zip               2707
# v6.2.0A.zip              2143
# v6.2.0B.zip              1540
# v6.2.0C.zip              1208
# v6.2.0D.zip              4079
# v6.2.0E.zip              3523
# v6.2.0F.zip              1216
# v6.2.2.zip               5170
# v6.2.2A.zip             12836
# v6.2.3.zip               8920
# v6.2.4.zip              17218
# v7.0.3H.zip              6161
# v7.0.3I.zip              1292
# v7.0.3J.zip              3284
# v7.0.3K.zip               773
# v7.0.3L.zip              3803
# v7.0.3M.zip              5498
# v7.0.3N.zip              8108
# v7.0.3O.zip               214
# veling%2Bv0.12.2.zip        1
# veling%2Bv0.12.3.zip        1
# dtype: float64

# %%
ax=data["2016"].dropna(axis=1, how='all').plot(kind='area', title="WoWPro Downloads 2014")

# %%
x = data["2015"].dropna(axis=1, how='all')
x = x.iloc[: , 9:]
ax=x.plot(kind='area', title="WoWPro Downloads 2015")
#ax.set_ylim(0,1000)
x.sum(axis=0)
# Out:
# v6.0.0D.zip        8
# v6.0.0E.zip      126
# v6.0.1.zip       622
# v6.0.2.zip         6
# v6.0.2A.zip      803
# v6.0.3.zip         1
# v6.0.3B.zip        1
# v6.0.3G.zip        2
# v6.0.3H.zip     1788
# v6.0.3J.zip     8200
# v6.0.4.zip      7397
# v6.1.0.zip      4253
# v6.1.1.zip      1425
# v6.1.1A.zip    13683
# v6.1.2.zip      4023
# v6.2.0.zip      2693
# v6.2.0A.zip     2142
# v6.2.0B.zip     1538
# v6.2.0C.zip     1207
# v6.2.0D.zip     4073
# v6.2.0E.zip     3522
# v6.2.0F.zip     1180
# v6.2.2.zip      5056
# v6.2.2A.zip    11300
# dtype: float64

# %%
x = data["2016"].dropna(axis=1, how='all')
x = x.iloc[: , -9:-2].dropna(axis=0, how='all')
ax=x.plot(kind='area', title="WoWPro Downloads 2016")
#ax.set_ylim(0,1000)
x.sum(axis=0)
# Out:
# v7.0.3I.zip    1292
# v7.0.3J.zip    3284
# v7.0.3K.zip     773
# v7.0.3L.zip    3803
# v7.0.3M.zip    5498
# v7.0.3N.zip    8108
# v7.0.3O.zip     214
# dtype: float64

# %%
x.resample('D', how='mean')
# Out:
#             v7.0.3I.zip  v7.0.3J.zip  v7.0.3K.zip  v7.0.3L.zip  v7.0.3M.zip  \
# 2016-07-30          687          NaN          NaN          NaN          NaN
# 2016-07-31          501           58          NaN          NaN          NaN
# 2016-08-01           54          571          NaN          NaN          NaN
# 2016-08-02            5          430          NaN          NaN          NaN
# 2016-08-03            1          310          NaN          NaN          NaN
# 2016-08-04            3          321          NaN          NaN          NaN
# 2016-08-05            2          319          NaN          NaN          NaN
# 2016-08-06            3          369          NaN          NaN          NaN
# 2016-08-07            3          391          NaN          NaN          NaN
# 2016-08-08            4          340          NaN          NaN          NaN
# 2016-08-09          NaN          134          512          NaN          NaN
# 2016-08-10            1          NaN          215          601          NaN
# 2016-08-11            1            4            3          505          NaN
# 2016-08-12          NaN          NaN          NaN          450          NaN
# 2016-08-13          NaN            2            4          496          NaN
# 2016-08-14            1            5            1          448          NaN
# 2016-08-15          NaN          NaN            4          336          NaN
# 2016-08-16          NaN            2            2          279          NaN
# 2016-08-17          NaN            2            4          266          NaN
# 2016-08-18          NaN          NaN          NaN          262          NaN
# 2016-08-19            1            1            2          111          257
# 2016-08-20            7          NaN          NaN            3          499
# 2016-08-21          NaN          NaN          NaN            2          406
# 2016-08-22          NaN          NaN          NaN          NaN          332
# 2016-08-23          NaN          NaN            1            1          281
# 2016-08-24            6            5            6            6          258
# 2016-08-25          NaN          NaN          NaN          NaN          220
# 2016-08-26          NaN            2            1            1          242
# 2016-08-27            3            1            2            4          273
# 2016-08-28          NaN            1          NaN          NaN          312
# 2016-08-29            5            4            4            7          577
# 2016-08-30          NaN            4            3            7         1690
# 2016-08-31          NaN          NaN            1            5          118
# 2016-09-01          NaN            2            3            4            9
# 2016-09-02            1          NaN            2          NaN            5
# 2016-09-03            1            3            2            3            6
# 2016-09-04            1          NaN          NaN            3            5
# 2016-09-05            1            2            1            2            5
# 2016-09-06          NaN            1          NaN            1            3
#
#             v7.0.3N.zip  v7.0.3O.zip
# 2016-07-30          NaN          NaN
# 2016-07-31          NaN          NaN
# 2016-08-01          NaN          NaN
# 2016-08-02          NaN          NaN
# 2016-08-03          NaN          NaN
# 2016-08-04          NaN          NaN
# 2016-08-05          NaN          NaN
# 2016-08-06          NaN          NaN
# 2016-08-07          NaN          NaN
# 2016-08-08          NaN          NaN
# 2016-08-09          NaN          NaN
# 2016-08-10          NaN          NaN
# 2016-08-11          NaN          NaN
# 2016-08-12          NaN          NaN
# 2016-08-13          NaN          NaN
# 2016-08-14          NaN          NaN
# 2016-08-15          NaN          NaN
# 2016-08-16          NaN          NaN
# 2016-08-17          NaN          NaN
# 2016-08-18          NaN          NaN
# 2016-08-19          NaN          NaN
# 2016-08-20          NaN          NaN
# 2016-08-21          NaN          NaN
# 2016-08-22          NaN          NaN
# 2016-08-23          NaN          NaN
# 2016-08-24          NaN          NaN
# 2016-08-25          NaN          NaN
# 2016-08-26          NaN          NaN
# 2016-08-27          NaN          NaN
# 2016-08-28          NaN          NaN
# 2016-08-29          NaN          NaN
# 2016-08-30          NaN          NaN
# 2016-08-31         2933          NaN
# 2016-09-01         1253          NaN
# 2016-09-02          935          NaN
# 2016-09-03          931          NaN
# 2016-09-04          870          NaN
# 2016-09-05          702          NaN
# 2016-09-06          484          214
